# %%
plt.figure()
plt.boxplot(df['AverageTemperature'].dropna())
plt.title("Temperature Outliers")
plt.ylabel("Temperature")
plt.show()

# %%
df['Month'] = df['dt'].dt.month
monthly_avg = df.groupby('Month')['AverageTemperature'].mean()

plt.figure()
plt.plot(monthly_avg)
plt.title("Average Temperature per Month")
plt.xlabel("Month")
plt.ylabel("Temperature")
plt.show()

# %%
cold_cities = df.groupby('City')['AverageTemperature'].mean().sort_values().head(10)

plt.figure()
cold_cities.plot(kind='bar')
plt.title("Top 10 Coldest Cities")
plt.xlabel("City")
plt.ylabel("Average Temperature")
plt.show()

# %%
top_cities = df.groupby('City')['AverageTemperature'].mean().sort_values(ascending=False).head(10)

plt.figure()
top_cities.plot(kind='bar')
plt.title("Top 10 Hottest Cities")
plt.xlabel("City")
plt.ylabel("Average Temperature")
plt.show()

# %%
plt.figure()
df['AverageTemperature'].hist(bins=50)
plt.title("Temperature Distribution")
plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

df['dt'] = pd.to_datetime(df['dt'])
yearly_temp = df.groupby(df['dt'].dt.year)['AverageTemperature'].mean()

plt.figure()
plt.plot(yearly_temp)
plt.title("Average Temperature Over Time")
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.show()

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()   # remove missing rows

# %%
df.isnull().sum()
# Out:
# dt                                    0
# AverageTemperature               364130
# AverageTemperatureUncertainty    364130
# City                                  0
# Country                               0
# Latitude                              0
# Longitude                             0
# dtype: int64
